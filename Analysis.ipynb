# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Load the CSV file
df = pd.read_csv('laptopPrice.csv')
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
# Display the first few rows of the dataframe
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %% [markdown]
# #### 1. . What are the average prices of laptops for each brand?

# %%
# Plot the average price by brand
plt.figure(figsize=(14, 7))
sns.barplot(x=average_prices_by_brand.index, y=average_prices_by_brand.values, palette='viridis')
plt.title('Average Price of Laptops by Brand')
plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
average_prices_by_brand = df.groupby('brand')['Price'].mean().sort_values(ascending=False)
average_prices_by_brand
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_26060\4005939533.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_prices_by_brand.index, y=average_prices_by_brand.values, palette='viridis')
# brand
# APPLE     151707.857143
# MSI        98713.020000
# ASUS       78937.602410
# HP         73640.272059
# Lenovo     72920.208333
# acer       72420.039216
# Avita      65157.428571
# DELL       60934.662252
# Name: Price, dtype: float64

# %% [markdown]
# ### 2.What is the distribution of ratings?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='rating')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 3. Is there a correlation between the amount of RAM and the price of the laptop?

# %%
# Convert RAM to numeric value
df['ram_gb'] = df['ram_gb'].str.replace(' GB', '').astype(int)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ram_gb', y='Price')
plt.title('RAM vs Price')
plt.xlabel('RAM (GB)')
plt.ylabel('Price')
plt.show()

# Calculate the correlation
ram_price_correlation = df['ram_gb'].corr(df['Price'])
ram_price_correlation
# Out:
# 0.5183226163080802

# %% [markdown]
# ### 4. What are the most common processor brands and their average prices?

# %%
# Calculate the processor brand counts
processor_brand_counts = df['processor_brand'].value_counts()

# Calculate the average price by processor brand
average_prices_by_processor_brand = df.groupby('processor_brand')['Price'].mean()

# Plot processor brand counts
plt.figure(figsize=(14, 7))
sns.barplot(x=processor_brand_counts.index, y=processor_brand_counts.values, palette='viridis')
plt.title('Processor Brand Counts')
plt.xlabel('Processor Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Plot average prices by processor brand
plt.figure(figsize=(14, 7))
sns.barplot(x=average_prices_by_processor_brand.index, y=average_prices_by_processor_brand.values, palette='viridis')
plt.title('Average Price by Processor Brand')
plt.xlabel('Processor Brand')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_26060\1924726172.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=processor_brand_counts.index, y=processor_brand_counts.values, palette='viridis')
# C:\Users\harsh\AppData\Local\Temp\ipykernel_26060\1924726172.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_prices_by_processor_brand.index, y=average_prices_by_processor_brand.values, palette='viridis')

# %% [markdown]
# ### 5. How does the presence of a touchscreen affect the price?

# %%
average_price_touchscreen = df.groupby('Touchscreen')['Price'].mean()
average_price_touchscreen
# Out:
# Touchscreen
# No      73629.163912
# Yes    100067.092784
# Name: Price, dtype: float64

# %%
# Prepare data for pie chart
labels = average_price_touchscreen.index
sizes = average_price_touchscreen.values

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff'])
plt.title('Average Price of Laptops With and Without Touchscreen')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### 6. What is the distribution of SSD sizes and how do they affect laptop prices?

# %%
# Convert all values in 'ssd' column to strings, then replace ' GB' and convert to integers
df['ssd'] = df['ssd'].astype(str).str.replace(' GB', '').astype(int)

# Plot the distribution of SSD sizes
plt.figure(figsize=(10, 6))
sns.histplot(df['ssd'], bins=20, kde=True)
plt.title('Distribution of SSD Sizes')
plt.xlabel('SSD Size (GB)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 7. What is the average price of laptops based on the type of operating system?

# %%
# Calculate the average price by OS
average_price_by_os = df.groupby('os')['Price'].mean()

# Plot the average price by OS
plt.figure(figsize=(12, 6))
sns.barplot(x=average_price_by_os.index, y=average_price_by_os.values, palette='viridis')
plt.title('Average Price of Laptops by Operating System')
plt.xlabel('Operating System')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_13580\1357739213.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_price_by_os.index, y=average_price_by_os.values, palette='viridis')

# %% [markdown]
# ### 8. How does the amount of SSD storage impact laptop prices?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ssd', y='Price')
plt.title('SSD Storage vs Price')
plt.xlabel('SSD Storage (GB)')
plt.ylabel('Price')
plt.show()

# Calculate the correlation
ssd_price_correlation = df['ssd'].corr(df['Price'])
ssd_price_correlation
# Out:
# 0.6282720286037492

# %% [markdown]
# ### 9. What is the relationship between the star rating and the price of laptops?

# %%
# Ensure all values in the 'rating' column are strings, then clean the column
df['rating'] = df['rating'].astype(str).str.replace(' stars', '').str.replace(' star', '').astype(float)

# Plot the Rating vs Price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='rating', y='Price')
plt.title('Star Rating vs Price')
plt.xlabel('Star Rating')
plt.ylabel('Price')
plt.show()
